# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# -100 ~ 100 사이의 값 중에 무작위 50개
data = np.random.randint(-100, 100, 50).cumsum()
data

# plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#1. 폰트파일로 fontProperties()
import matplotlib.font_manager as fm
path = 'D2CODING.TTF'
fontprop = fm.FontProperties(fname=path, size=14)

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False
print('기본 설정 폰트:', plt.rcParams['font.family'])
print('기본 폰트 크기:', plt.rcParams['font.size'])
# Out:
# 기본 설정 폰트: ['Malgun Gothic']
# 기본 폰트 크기: 12.0

# %%
# -100 ~ 100 사이의 값 중에 무작위 50개
data = np.random.randint(-100, 100, 50).cumsum()

# plt.rc('font', family='Gulim')
plt.plot(range(50), data, 'r')
# plt.title('시간별 가격 추이', fontproperties=fontprop)
# plt.ylabel('주식가격', fontproperties=fontprop)
# plt.xlabel('시간(분)', fontproperties=fontprop)
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#2. rcParams[]를 설정

import matplotlib


print('설정파일위치:', matplotlib.matplotlib_fname())
print('기본 설정 폰트:', plt.rcParams['font.family'])
print('기본 폰트 크기:', plt.rcParams['font.size'])
# Out:
# 설정파일위치: C:\venv\venv_pandas\Lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트: ['Malgun Gothic']
# 기본 폰트 크기: 12.0

# %%
#3. 설정파일에 셋팅
print('설정파일위치:', matplotlib.matplotlib_fname())
[ font.name for font in fm.fontManager.ttflist if 'Nanum' in font.name]
# Out:
# 설정파일위치: C:\venv\venv_pandas\Lib\site-packages\matplotlib\mpl-data\matplotlibrc
# ['NanumSquare',
#  'NanumSquare_ac',
#  'NanumSquare',
#  'NanumSquare_ac',
#  'NanumSquare_ac',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquare_ac']
