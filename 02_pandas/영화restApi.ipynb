# %%
key='ea996a36aacc9ba170b113d635279423'
targetDt='20230409'

# %%
url =f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={targetDt}'

# %%
import urllib.request
import json
import pandas as pd
import time,datetime

# %%
r = urllib.request.urlopen(url)
# print(r.read().decode('utf8'))
data = json.loads(r.read())
data['boxOfficeResult']['dailyBoxOfficeList']
# Out:
# [{'rnum': '1',
#   'rank': '1',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20226270',
#   'movieNm': '스즈메의 문단속',
#   'openDt': '2023-03-08',
#   'salesAmt': '1545941390',
#   'salesShare': '46.1',
#   'salesInten': '-343681878',
#   'salesChange': '-18.2',
#   'salesAcc': '44785691803',
#   'audiCnt': '154556',
#   'audiInten': '-33196',
#   'audiChange': '-17.7',
#   'audiAcc': '4344056',
#   'scrnCnt': '1323',
#   'showCnt': '5109'},
#  {'rnum': '2',
#   'rank': '2',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20226489',
#   'movieNm': '리바운드',
#   'openDt': '2023-04-05',
#   'salesAmt': '802910347',
#   'salesShare': '23.9',
#   'salesInten': '-84289396',
#   'salesChange': '-9.5',
#   'salesAcc': '2769555376',
#   'audiCnt': '82900',
#   'audiInten': '-7973',
#   'audiChange': '-8.8',
#   'audiAcc': '290164',
#   'scrnCnt': '1154',
#   'showCnt': '4413'},
#  {'rnum': '3',
#   'rank': '3',
#   'rankInten': '1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231089',
#   'movieNm': '존 윅 4',
#   'openDt': '2023-04-12',
#   'salesAmt': '207880297',
#   'salesShare': '6.2',
#   'salesInten': '-22572911',
#   'salesChange': '-9.8',
#   'salesAcc': '459549505',
#   'audiCnt': '17996',
#   'audiInten': '-1904',
#   'audiChange': '-9.6',
#   'audiAcc': '39144',
#   'scrnCnt': '173',
#   'showCnt': '364'},
#  {'rnum': '4',
#   'rank': '4',
#   'rankInten': '-1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20226410',
#   'movieNm': '던전 앤 드래곤: 도적들의 명예',
#   'openDt': '2023-03-29',
#   'salesAmt': '168895437',
#   'salesShare': '5.0',
#   'salesInten': '-50248169',
#   'salesChange': '-22.9',
#   'salesAcc': '2666060307',
#   'audiCnt': '16721',
#   'audiInten': '-4636',
#   'audiChange': '-21.7',
#   'audiAcc': '267944',
#   'scrnCnt': '623',
#   'showCnt': '1317'},
#  {'rnum': '5',
#   'rank': '5',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231010',
#   'movieNm': '에어',
#   'openDt': '2023-04-05',
#   'salesAmt': '145271413',
#   'salesShare': '4.3',
#   'salesInten': '-52693051',
#   'salesChange': '-26.6',
#   'salesAcc': '750911362',
#   'audiCnt': '14494',
#   'audiInten': '-5402',
#   'audiChange': '-27.2',
#   'audiAcc': '77552',
#   'scrnCnt': '629',
#   'showCnt': '1962'},
#  {'rnum': '6',
#   'rank': '6',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20228555',
#   'movieNm': '더 퍼스트 슬램덩크',
#   'openDt': '2023-01-04',
#   'salesAmt': '188916500',
#   'salesShare': '5.6',
#   'salesInten': '-37243500',
#   'salesChange': '-16.5',
#   'salesAcc': '46190437867',
#   'audiCnt': '10805',
#   'audiInten': '-1836',
#   'audiChange': '-14.5',
#   'audiAcc': '4447450',
#   'scrnCnt': '22',
#   'showCnt': '126'},
#  {'rnum': '7',
#   'rank': '7',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20210544',
#   'movieNm': '웅남이',
#   'openDt': '2023-03-22',
#   'salesAmt': '44281046',
#   'salesShare': '1.3',
#   'salesInten': '-4838843',
#   'salesChange': '-9.9',
#   'salesAcc': '2725483652',
#   'audiCnt': '4793',
#   'audiInten': '-566',
#   'audiChange': '-10.6',
#   'audiAcc': '297333',
#   'scrnCnt': '363',
#   'showCnt': '558'},
#  {'rnum': '8',
#   'rank': '8',
#   'rankInten': '1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20230484',
#   'movieNm': '치킨래빗: 잃어버린 보물을 찾아서',
#   'openDt': '2023-03-18',
#   'salesAmt': '33462000',
#   'salesShare': '1.0',
#   'salesInten': '-1266500',
#   'salesChange': '-3.6',
#   'salesAcc': '546366000',
#   'audiCnt': '3557',
#   'audiInten': '6',
#   'audiChange': '0.2',
#   'audiAcc': '61162',
#   'scrnCnt': '138',
#   'showCnt': '208'},
#  {'rnum': '9',
#   'rank': '9',
#   'rankInten': '-1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20230764',
#   'movieNm': '오글리스: 웰컴 투 냄새 마을',
#   'openDt': '2023-04-06',
#   'salesAmt': '30223090',
#   'salesShare': '0.9',
#   'salesInten': '-1948798',
#   'salesChange': '-6.1',
#   'salesAcc': '74771876',
#   'audiCnt': '3406',
#   'audiInten': '-223',
#   'audiChange': '-6.1',
#   'audiAcc': '8611',
#   'scrnCnt': '249',
#   'showCnt': '294'},
#  {'rnum': '10',
#   'rank': '10',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231035',
#   'movieNm': '카구야 님은 고백받고 싶어 -첫 키스는 끝나지 않아-',
#   'openDt': '2023-04-06',
#   'salesAmt': '27178300',
#   'salesShare': '0.8',
#   'salesInten': '-12885900',
#   'salesChange': '-32.2',
#   'salesAcc': '136089900',
#   'audiCnt': '2383',
#   'audiInten': '-1137',
#   'audiChange': '-32.3',
#   'audiAcc': '11980',
#   'scrnCnt': '107',
#   'showCnt': '221'}]

# %%
movieDate = time.strftime('%Y%m%d',time.localtime(time.time()))
movieDate
date_obj = datetime.datetime.strptime(movieDate,'%Y%m%d')
date_obj
# Out:
# datetime.datetime(2023, 4, 10, 0, 0)

# %%
def cineBoxInfo():
    movieDate = time.strftime('%Y%m%d',time.localtime(time.time()))
    cine=[]
    for i in range(30):
        date_obj = datetime.datetime.strptime(movieDate,'%Y%m%d')
        date_obj_temp = date_obj - datetime.timedelta(days=1)
        movieDate = date_obj_temp.strftime('%Y%m%d')
        print(movieDate,end=" ")
        url =f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={movieDate}'
        r = urllib.request.urlopen(url)
        data = json.loads(r.read())
        result = data['boxOfficeResult']['dailyBoxOfficeList']
        for i in range(len(result)):
            result[i]['targetDt'] = movieDate
            cine.append(result[i])
    df = pd.DataFrame(cine)
    df.to_csv('cine.csv',index=False)
    return df

# %%
cineBoxInfo()
# Out:
# 20230409 20230408 20230407 20230406 20230405 20230404 20230403 20230402 20230401 20230331 20230330 20230329 20230328 20230327 20230326 20230325 20230324 20230323 20230322 20230321 20230320 20230319 20230318 20230317 20230316 20230315 20230314 20230313 20230312 20230311
#     rnum rank rankInten rankOldAndNew   movieCd            movieNm
# 0      1    1         0           OLD  20226270           스즈메의 문단속  \
# 1      2    2         0           OLD  20226489               리바운드
# 2      3    3         1           OLD  20231089              존 윅 4
# 3      4    4        -1           OLD  20226410  던전 앤 드래곤: 도적들의 명예
# 4      5    5         0           OLD  20231010                 에어
# ..   ...  ...       ...           ...       ...                ...
# 295    6    6         0           OLD  20239573               서치 2
# 296    7    7        -2           OLD  20230495       아임 히어로 더 파이널
# 297    8    8        -1           OLD  20230209    앤트맨과 와스프: 퀀텀매니아
# 298    9    9         1           OLD  20193706                카운트
# 299   10   10        -1           OLD  20230200                똑똑똑
#
#          openDt    salesAmt salesShare  salesInten salesChange     salesAcc
# 0    2023-03-08  1545941390       46.1  -343681878       -18.2  44785691803  \
# 1    2023-04-05   802910347       23.9   -84289396        -9.5   2769555376
# 2    2023-04-12   207880297        6.2   -22572911        -9.8    459549505
# 3    2023-03-29   168895437        5.0   -50248169       -22.9   2666060307
# 4    2023-04-05   145271413        4.3   -52693051       -26.6    750911362
# ..          ...         ...        ...         ...         ...          ...
# 295  2023-02-22   100397802        1.8    58025355       136.9   3800189425
# 296  2023-03-01   201068500        3.7    83020500        70.3   4313984000
# 297  2023-02-15    74500433        1.4    40666470       120.2  16190619697
# 298  2023-02-22    44672666        0.8    22869680       104.9   3588564187
# 299  2023-03-08    43867168        0.8    13903879        46.4    176241737
#
#     audiCnt audiInten audiChange  audiAcc scrnCnt showCnt  targetDt
# 0    154556    -33196      -17.7  4344056    1323    5109  20230409
# 1     82900     -7973       -8.8   290164    1154    4413  20230409
# 2     17996     -1904       -9.6    39144     173     364  20230409
# 3     16721     -4636      -21.7   267944     623    1317  20230409
# 4     14494     -5402      -27.2    77552     629    1962  20230409
# ..      ...       ...        ...      ...     ...     ...       ...
# 295    9694      5302      120.7   386559     450     681  20230311
# 296    8381      3462       70.4   178636      78     290  20230311
# 297    7020      3553      102.5  1535994     437     690  20230311
# 298    4406      2125       93.2   376749     382     535  20230311
# 299    4267      1262         42    17964     457     913  20230311
#
# [300 rows x 19 columns]
